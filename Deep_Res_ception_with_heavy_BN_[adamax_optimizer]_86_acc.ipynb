# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip '/content/drive/My Drive/DATASETS/intel-image-classification.zip' -d 'intel-image-classification/'
# Out:
# Archive:  /content/drive/My Drive/DATASETS/intel-image-classification.zip
#   inflating: intel-image-classification/seg_train.zip
#   inflating: intel-image-classification/seg_test.zip
#   inflating: intel-image-classification/seg_pred.zip

# %%
# !unzip 'intel-image-classification/seg_train.zip' -d 'intel-image-classification/seg_train/'
# !unzip 'intel-image-classification/seg_test.zip' -d 'intel-image-classification/seg_test/'
# !unzip 'intel-image-classification/seg_pred.zip' -d 'intel-image-classification/seg_pred/'

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Input, ZeroPadding2D, Conv2D, MaxPooling2D, Activation, add
from keras.utils import to_categorical
from keras.preprocessing import image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

import tensorflow.keras
from tensorflow.keras.layers import Conv2D, Dropout, MaxPool2D, AvgPool2D, Add, Dense 
from tensorflow.keras.preprocessing.image import load_img, img_to_array


from keras.models import Model

from keras.utils import plot_model

import warnings
#warnings.warn("ignore")
import os
# Out:
# Using TensorFlow backend.

# %%
#!unzip 'intel-image-classification.zip'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

image_width, image_height = 150,150


train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    shear_range = 0.2,
                    zoom_range = 0.2,
                    horizontal_flip=True,
                    validation_split=0.25
)


train_generator = train_datagen.flow_from_directory(
                    directory= "intel-image-classification/seg_train/seg_train/",
                    batch_size=128,
                    seed=42,
                    shuffle=True,
                    class_mode="categorical",
                    target_size=(image_width, image_height))     

test_datagen.
test_generator =  test_datagen.flow_from_directory(
                    directory="intel-image-classification/seg_test/seg_test/",
                    batch_size=128,
                    seed=42,
                    shuffle=True,
                    class_mode="categorical",
                    target_size=(image_width, image_height))
# Out:
# Found 14034 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.

# %%
def inception_module(layer_in, f1, f2_in, f2_out, f3_in, f3_out, f4_out):
    # 1x1 conv
    conv1 = Conv2D(f1, (1,1), padding='same', activation='relu')(layer_in)
    # 3x3 conv
    conv3 = Conv2D(f2_in, (1,1), padding='same', activation='relu')(layer_in)
    conv3 = Conv2D(f2_out, (3,3), padding='same', activation='relu')(conv3)
    # 5x5 conv
    conv5 = Conv2D(f3_in, (1,1), padding='same', activation='relu')(layer_in)
    conv5 = Conv2D(f3_out, (5,5), padding='same', activation='relu')(conv5)
    # 3x3 max pooling
    pool = MaxPooling2D((3,3), strides=(1,1), padding='same')(layer_in)
    pool = Conv2D(f4_out, (1,1), padding='same', activation='relu')(pool)
    # concatenate filters, assumes filters/channels last
    layer_out = concatenate([conv1, conv3, conv5, pool], axis=-1)
    return layer_out

# %%
def identity_block(X, f, filters, stage, block):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value. We'll need this later to add back to the main path. 
    X_shortcut = X

    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X
    

    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    
    ##### SHORTCUT PATH ####
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
def DeepResNetInception(input_shape = (150, 150, 3), classes = 6):   
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

   
    # Zero-Padding
    #X = ZeroPadding2D((3, 3))(X_input)
    X = X_input
    
    # Stage 1
    X = Conv2D(16, (3, 3), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)

    # Stage 2
    X = Conv2D(32, (3, 3), strides = (2, 2), name = 'conv2', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv2')(X)
    X = Activation('relu')(X)

    
    # Stage 3
    X = Conv2D(64, (3, 3), strides = (2, 2), name = 'conv3', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv3')(X)
    X = Activation('relu')(X)
       

    # inception module (out 128)
    X = inception_module(X, f1=32, f2_in=(32+8), f2_out=64, f3_in=8, f3_out=16, f4_out=16)
    X = BatchNormalization(axis = 3, name = 'bn_conv4')(X)
    X = Activation('relu')(X)    

    # Stage 5
    X = convolutional_block(X, f = 3, filters = [128, 128, 256], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 256], stage=4, block='b')
    X = BatchNormalization(axis = 3, name = 'bn_conv5')(X)
    X = Activation('relu')(X)    
    
    # inception module (out 256)
    X = inception_module(X, f1=64, f2_in=(64+16), f2_out=128, f3_in=16, f3_out=32, f4_out=32)
    X = BatchNormalization(axis = 3, name = 'bn_conv6')(X)
    X = Activation('relu')(X)    

    # Stage 5
    X = convolutional_block(X, f = 3, filters = [256, 256, 512], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 512], stage=5, block='b')
    X = BatchNormalization(axis = 3, name = 'bn_conv7')(X)
    X = Activation('relu')(X)
    
    # inception module (out 512)
    X = inception_module(X, f1=128, f2_in=(128+32), f2_out=256, f3_in=32, f3_out=64, f4_out=64)
    X = BatchNormalization(axis = 3, name = 'bn_conv8')(X)
    X = Activation('relu')(X)    

    # Stage 5
    X = convolutional_block(X, f = 3, filters = [512, 512, 1024], stage = 6, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 1024], stage=6, block='b')
    X = BatchNormalization(axis = 3, name = 'bn_conv9')(X)
    X = Activation('relu')(X)    



    # AVGPOOL
    X = AveragePooling2D((2, 2), name='avg_pool')(X)

    # output layer
    X = Flatten()(X)
    #X = Dropout(0.25)(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes),  kernel_initializer = glorot_uniform(seed=0))(X)
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='DeepRes-ception')

    return model

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import cv2
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D
from keras.models import Model, load_model
from keras.initializers import glorot_uniform
from keras.utils import plot_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import keras.backend as K
import tensorflow as tf

from keras.layers.merge import concatenate

from keras import regularizers

# %%
img_shape = (150, 150, 3)
model = DeepResNetInception(input_shape=img_shape, classes=6)

# %%
model.summary()
# Out:
# Model: "DeepRes-ception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 150, 150, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 74, 74, 16)   448         input_3[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 74, 74, 16)   64          conv1[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 74, 74, 16)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 36, 36, 32)   4640        activation_55[0][0]
# __________________________________________________________________________________________________
# bn_conv2 (BatchNormalization)   (None, 36, 36, 32)   128         conv2[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 36, 36, 32)   0           bn_conv2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 17, 17, 64)   18496       activation_56[0][0]
# __________________________________________________________________________________________________
# bn_conv3 (BatchNormalization)   (None, 17, 17, 64)   256         conv3[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 64)   0           bn_conv3[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 40)   2600        activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 8)    520         activation_57[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 17, 17, 64)   0           activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 32)   2080        activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 64)   23104       conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 16)   3216        conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 16)   1040        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 17, 17, 128)  0           conv2d_37[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# bn_conv4 (BatchNormalization)   (None, 17, 17, 128)  512         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 128)  0           bn_conv4[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 9, 9, 128)    16512       activation_58[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 9, 9, 128)    512         res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 9, 9, 128)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 9, 9, 128)    147584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 9, 9, 128)    512         res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 9, 9, 128)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 9, 9, 256)    33024       activation_60[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 9, 9, 256)    33024       activation_58[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 9, 9, 256)    1024        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 9, 9, 256)    1024        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 9, 9, 256)    0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 9, 9, 256)    0           add_13[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 9, 9, 128)    32896       activation_61[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 9, 9, 128)    512         res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 9, 9, 128)    0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 9, 9, 128)    147584      activation_62[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 9, 9, 128)    512         res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 9, 9, 128)    0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 9, 9, 256)    33024       activation_63[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 9, 9, 256)    1024        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 9, 9, 256)    0           bn4b_branch2c[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 9, 9, 256)    0           add_14[0][0]
# __________________________________________________________________________________________________
# bn_conv5 (BatchNormalization)   (None, 9, 9, 256)    1024        activation_64[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 9, 9, 256)    0           bn_conv5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 9, 9, 80)     20560       activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 9, 9, 16)     4112        activation_65[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 9, 9, 256)    0           activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 9, 9, 64)     16448       activation_65[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 9, 9, 128)    92288       conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 9, 9, 32)     12832       conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 9, 9, 32)     8224        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 9, 9, 256)    0           conv2d_43[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# bn_conv6 (BatchNormalization)   (None, 9, 9, 256)    1024        concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 9, 9, 256)    0           bn_conv6[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 5, 5, 256)    65792       activation_66[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 5, 5, 256)    1024        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 5, 5, 256)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 5, 5, 256)    590080      activation_67[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 5, 5, 256)    1024        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 5, 5, 256)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 5, 5, 512)    131584      activation_68[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 5, 5, 512)    131584      activation_66[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 5, 5, 512)    2048        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 5, 5, 512)    2048        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 5, 5, 512)    0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 5, 5, 512)    0           add_15[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 5, 5, 256)    131328      activation_69[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 5, 5, 256)    1024        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 5, 5, 256)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 5, 5, 256)    590080      activation_70[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 5, 5, 256)    1024        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 5, 5, 256)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 5, 5, 512)    131584      activation_71[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 5, 5, 512)    2048        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 5, 5, 512)    0           bn5b_branch2c[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 5, 5, 512)    0           add_16[0][0]
# __________________________________________________________________________________________________
# bn_conv7 (BatchNormalization)   (None, 5, 5, 512)    2048        activation_72[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 5, 5, 512)    0           bn_conv7[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 5, 5, 160)    82080       activation_73[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 5, 5, 32)     16416       activation_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 5, 5, 512)    0           activation_73[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 5, 5, 128)    65664       activation_73[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 5, 5, 256)    368896      conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 5, 5, 64)     51264       conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 5, 5, 64)     32832       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 5, 5, 512)    0           conv2d_49[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# bn_conv8 (BatchNormalization)   (None, 5, 5, 512)    2048        concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 5, 5, 512)    0           bn_conv8[0][0]
# __________________________________________________________________________________________________
# res6a_branch2a (Conv2D)         (None, 3, 3, 512)    262656      activation_74[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2a (BatchNormalizati (None, 3, 3, 512)    2048        res6a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 3, 3, 512)    0           bn6a_branch2a[0][0]
# __________________________________________________________________________________________________
# res6a_branch2b (Conv2D)         (None, 3, 3, 512)    2359808     activation_75[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2b (BatchNormalizati (None, 3, 3, 512)    2048        res6a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 3, 3, 512)    0           bn6a_branch2b[0][0]
# __________________________________________________________________________________________________
# res6a_branch2c (Conv2D)         (None, 3, 3, 1024)   525312      activation_76[0][0]
# __________________________________________________________________________________________________
# res6a_branch1 (Conv2D)          (None, 3, 3, 1024)   525312      activation_74[0][0]
# __________________________________________________________________________________________________
# bn6a_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res6a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn6a_branch1 (BatchNormalizatio (None, 3, 3, 1024)   4096        res6a_branch1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 3, 3, 1024)   0           bn6a_branch2c[0][0]
#                                                                  bn6a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 3, 3, 1024)   0           add_17[0][0]
# __________________________________________________________________________________________________
# res6b_branch2a (Conv2D)         (None, 3, 3, 512)    524800      activation_77[0][0]
# __________________________________________________________________________________________________
# bn6b_branch2a (BatchNormalizati (None, 3, 3, 512)    2048        res6b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 3, 3, 512)    0           bn6b_branch2a[0][0]
# __________________________________________________________________________________________________
# res6b_branch2b (Conv2D)         (None, 3, 3, 512)    2359808     activation_78[0][0]
# __________________________________________________________________________________________________
# bn6b_branch2b (BatchNormalizati (None, 3, 3, 512)    2048        res6b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 3, 3, 512)    0           bn6b_branch2b[0][0]
# __________________________________________________________________________________________________
# res6b_branch2c (Conv2D)         (None, 3, 3, 1024)   525312      activation_79[0][0]
# __________________________________________________________________________________________________
# bn6b_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res6b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 3, 3, 1024)   0           bn6b_branch2c[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 3, 3, 1024)   0           add_18[0][0]
# __________________________________________________________________________________________________
# bn_conv9 (BatchNormalization)   (None, 3, 3, 1024)   4096        activation_80[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 3, 3, 1024)   0           bn_conv9[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 1024)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1024)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc6 (Dense)                     (None, 6)            6150        flatten_3[0][0]
# ==================================================================================================
# Total params: 10,179,638
# Trainable params: 10,156,118
# Non-trainable params: 23,520
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adamax', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
len(model.layers)
# Out:
# 115

# %%
# fits the model on batches with real-time data augmentation:
trained_model = model.fit_generator(
            train_generator,
            validation_data=test_generator,
            epochs=75
)
# Out:
# Epoch 1/75
# 110/110 [==============================] - 106s 960ms/step - loss: 1.4784 - acc: 0.4951 - val_loss: 1.6995 - val_acc: 0.4660
# Epoch 2/75
# 110/110 [==============================] - 97s 880ms/step - loss: 1.0859 - acc: 0.6280 - val_loss: 1.3411 - val_acc: 0.5653
# Epoch 3/75
# 110/110 [==============================] - 98s 888ms/step - loss: 0.9678 - acc: 0.6630 - val_loss: 1.1248 - val_acc: 0.6310
# Epoch 4/75
# 110/110 [==============================] - 98s 889ms/step - loss: 0.9043 - acc: 0.6829 - val_loss: 0.9875 - val_acc: 0.6590
# Epoch 5/75
# 110/110 [==============================] - 98s 890ms/step - loss: 0.8365 - acc: 0.7080 - val_loss: 0.8840 - val_acc: 0.6867
# Epoch 6/75
# 110/110 [==============================] - 98s 889ms/step - loss: 0.7981 - acc: 0.7196 - val_loss: 0.8267 - val_acc: 0.7163
# Epoch 7/75
# 110/110 [==============================] - 98s 889ms/step - loss: 0.7587 - acc: 0.7340 - val_loss: 0.9166 - val_acc: 0.6847
# Epoch 8/75
# 110/110 [==============================] - 98s 889ms/step - loss: 0.7211 - acc: 0.7447 - val_loss: 0.7938 - val_acc: 0.7003
# Epoch 9/75
# 110/110 [==============================] - 98s 892ms/step - loss: 0.6896 - acc: 0.7557 - val_loss: 0.7691 - val_acc: 0.7257
# Epoch 10/75
# 110/110 [==============================] - 98s 890ms/step - loss: 0.6752 - acc: 0.7616 - val_loss: 0.7815 - val_acc: 0.7197
# Epoch 11/75
# 110/110 [==============================] - 98s 888ms/step - loss: 0.6442 - acc: 0.7712 - val_loss: 0.8231 - val_acc: 0.7233
# Epoch 12/75
# 110/110 [==============================] - 97s 886ms/step - loss: 0.6331 - acc: 0.7765 - val_loss: 0.7001 - val_acc: 0.7527
# Epoch 13/75
# 110/110 [==============================] - 97s 885ms/step - loss: 0.5997 - acc: 0.7851 - val_loss: 0.7402 - val_acc: 0.7343
# Epoch 14/75
# 110/110 [==============================] - 97s 883ms/step - loss: 0.5938 - acc: 0.7898 - val_loss: 0.7105 - val_acc: 0.7540
# Epoch 15/75
# 110/110 [==============================] - 97s 882ms/step - loss: 0.5671 - acc: 0.7952 - val_loss: 0.7172 - val_acc: 0.7567
# Epoch 16/75
# 110/110 [==============================] - 97s 882ms/step - loss: 0.5622 - acc: 0.7999 - val_loss: 0.7448 - val_acc: 0.7430
# Epoch 17/75
# 110/110 [==============================] - 97s 886ms/step - loss: 0.5472 - acc: 0.8035 - val_loss: 0.8455 - val_acc: 0.7087
# Epoch 18/75
# 110/110 [==============================] - 98s 889ms/step - loss: 0.5267 - acc: 0.8087 - val_loss: 0.5273 - val_acc: 0.8090
# Epoch 19/75
# 110/110 [==============================] - 97s 884ms/step - loss: 0.5181 - acc: 0.8146 - val_loss: 0.5788 - val_acc: 0.7970
# Epoch 20/75
# 110/110 [==============================] - 97s 882ms/step - loss: 0.5193 - acc: 0.8133 - val_loss: 0.7802 - val_acc: 0.7360
# Epoch 21/75
# 110/110 [==============================] - 97s 880ms/step - loss: 0.5047 - acc: 0.8232 - val_loss: 0.6408 - val_acc: 0.7830
# Epoch 22/75
# 110/110 [==============================] - 97s 886ms/step - loss: 0.5010 - acc: 0.8218 - val_loss: 0.5669 - val_acc: 0.7990
# Epoch 23/75
# 110/110 [==============================] - 97s 885ms/step - loss: 0.4794 - acc: 0.8282 - val_loss: 0.6434 - val_acc: 0.7737
# Epoch 24/75
# 110/110 [==============================] - 98s 889ms/step - loss: 0.4771 - acc: 0.8293 - val_loss: 0.6991 - val_acc: 0.7597
# Epoch 25/75
# 110/110 [==============================] - 98s 892ms/step - loss: 0.4627 - acc: 0.8363 - val_loss: 0.7824 - val_acc: 0.7337
# Epoch 26/75
# 110/110 [==============================] - 98s 889ms/step - loss: 0.4582 - acc: 0.8369 - val_loss: 0.6930 - val_acc: 0.7597
# Epoch 27/75
# 110/110 [==============================] - 98s 888ms/step - loss: 0.4489 - acc: 0.8416 - val_loss: 0.5424 - val_acc: 0.8153
# Epoch 28/75
# 110/110 [==============================] - 98s 890ms/step - loss: 0.4452 - acc: 0.8390 - val_loss: 0.8291 - val_acc: 0.7323
# Epoch 29/75
# 110/110 [==============================] - 98s 887ms/step - loss: 0.4329 - acc: 0.8451 - val_loss: 0.6591 - val_acc: 0.7673
# Epoch 30/75
# 110/110 [==============================] - 98s 889ms/step - loss: 0.4230 - acc: 0.8475 - val_loss: 0.8505 - val_acc: 0.7207
# Epoch 31/75
# 110/110 [==============================] - 98s 891ms/step - loss: 0.4212 - acc: 0.8481 - val_loss: 0.4922 - val_acc: 0.8227
# Epoch 32/75
# 110/110 [==============================] - 98s 891ms/step - loss: 0.4084 - acc: 0.8550 - val_loss: 0.5186 - val_acc: 0.8203
# Epoch 33/75
# 110/110 [==============================] - 98s 891ms/step - loss: 0.4035 - acc: 0.8561 - val_loss: 0.7523 - val_acc: 0.7400
# Epoch 34/75
# 110/110 [==============================] - 98s 892ms/step - loss: 0.3950 - acc: 0.8608 - val_loss: 0.6432 - val_acc: 0.7827
# Epoch 35/75
# 110/110 [==============================] - 98s 893ms/step - loss: 0.3934 - acc: 0.8609 - val_loss: 0.5311 - val_acc: 0.8207
# Epoch 36/75
# 110/110 [==============================] - 98s 891ms/step - loss: 0.3770 - acc: 0.8669 - val_loss: 0.6037 - val_acc: 0.8023
# Epoch 37/75
# 110/110 [==============================] - 98s 892ms/step - loss: 0.3760 - acc: 0.8650 - val_loss: 0.6732 - val_acc: 0.7580
# Epoch 38/75
# 110/110 [==============================] - 97s 886ms/step - loss: 0.3703 - acc: 0.8684 - val_loss: 0.5423 - val_acc: 0.8137
# Epoch 39/75
# 110/110 [==============================] - 97s 885ms/step - loss: 0.3501 - acc: 0.8761 - val_loss: 1.1582 - val_acc: 0.6550
# Epoch 40/75
# 110/110 [==============================] - 99s 897ms/step - loss: 0.3560 - acc: 0.8773 - val_loss: 0.5064 - val_acc: 0.8200
# Epoch 41/75
# 110/110 [==============================] - 98s 894ms/step - loss: 0.3428 - acc: 0.8773 - val_loss: 0.5772 - val_acc: 0.8020
# Epoch 42/75
# 110/110 [==============================] - 99s 897ms/step - loss: 0.3362 - acc: 0.8802 - val_loss: 0.4741 - val_acc: 0.8407
# Epoch 43/75
# 110/110 [==============================] - 98s 889ms/step - loss: 0.3351 - acc: 0.8810 - val_loss: 0.6159 - val_acc: 0.7987
# Epoch 44/75
# 110/110 [==============================] - 97s 885ms/step - loss: 0.3328 - acc: 0.8825 - val_loss: 0.6147 - val_acc: 0.7987
# Epoch 45/75
# 110/110 [==============================] - 97s 884ms/step - loss: 0.3205 - acc: 0.8868 - val_loss: 0.6746 - val_acc: 0.7710
# Epoch 46/75
# 110/110 [==============================] - 97s 885ms/step - loss: 0.3239 - acc: 0.8849 - val_loss: 0.8092 - val_acc: 0.7470
# Epoch 47/75
# 110/110 [==============================] - 97s 886ms/step - loss: 0.3189 - acc: 0.8845 - val_loss: 0.5013 - val_acc: 0.8287
# Epoch 48/75
# 110/110 [==============================] - 97s 885ms/step - loss: 0.3110 - acc: 0.8895 - val_loss: 0.8829 - val_acc: 0.7343
# Epoch 49/75
# 110/110 [==============================] - 97s 884ms/step - loss: 0.3082 - acc: 0.8899 - val_loss: 0.6010 - val_acc: 0.8010
# Epoch 50/75
# 110/110 [==============================] - 98s 887ms/step - loss: 0.2979 - acc: 0.8944 - val_loss: 0.5468 - val_acc: 0.8227
# Epoch 51/75
# 110/110 [==============================] - 97s 884ms/step - loss: 0.2969 - acc: 0.8931 - val_loss: 0.4993 - val_acc: 0.8300
# Epoch 52/75
# 110/110 [==============================] - 98s 888ms/step - loss: 0.2885 - acc: 0.8939 - val_loss: 0.6652 - val_acc: 0.7893
# Epoch 53/75
# 110/110 [==============================] - 98s 887ms/step - loss: 0.2903 - acc: 0.8980 - val_loss: 0.4170 - val_acc: 0.8563
# Epoch 54/75
# 110/110 [==============================] - 97s 886ms/step - loss: 0.2840 - acc: 0.8985 - val_loss: 0.6037 - val_acc: 0.8140
# Epoch 55/75
# 110/110 [==============================] - 98s 886ms/step - loss: 0.2822 - acc: 0.9013 - val_loss: 0.5500 - val_acc: 0.8243
# Epoch 56/75
# 110/110 [==============================] - 96s 876ms/step - loss: 0.2702 - acc: 0.9019 - val_loss: 0.4915 - val_acc: 0.8447
# Epoch 57/75
# 110/110 [==============================] - 96s 874ms/step - loss: 0.2731 - acc: 0.9026 - val_loss: 0.5439 - val_acc: 0.8143
# Epoch 58/75
# 110/110 [==============================] - 96s 876ms/step - loss: 0.2703 - acc: 0.9020 - val_loss: 0.4589 - val_acc: 0.8493
# Epoch 59/75
# 110/110 [==============================] - 96s 874ms/step - loss: 0.2527 - acc: 0.9108 - val_loss: 0.9058 - val_acc: 0.7433
# Epoch 60/75
# 110/110 [==============================] - 97s 877ms/step - loss: 0.2566 - acc: 0.9094 - val_loss: 0.5427 - val_acc: 0.8237
# Epoch 61/75
# 110/110 [==============================] - 96s 874ms/step - loss: 0.2573 - acc: 0.9086 - val_loss: 1.1095 - val_acc: 0.6960
# Epoch 62/75
# 110/110 [==============================] - 96s 876ms/step - loss: 0.2452 - acc: 0.9093 - val_loss: 0.5290 - val_acc: 0.8297
# Epoch 63/75
# 110/110 [==============================] - 96s 874ms/step - loss: 0.2465 - acc: 0.9143 - val_loss: 0.6321 - val_acc: 0.7993
# Epoch 64/75
# 110/110 [==============================] - 96s 876ms/step - loss: 0.2477 - acc: 0.9111 - val_loss: 0.5865 - val_acc: 0.8233
# Epoch 65/75
# 110/110 [==============================] - 96s 876ms/step - loss: 0.2460 - acc: 0.9144 - val_loss: 0.5238 - val_acc: 0.8403
# Epoch 66/75
# 110/110 [==============================] - 97s 877ms/step - loss: 0.2375 - acc: 0.9146 - val_loss: 0.5988 - val_acc: 0.8113
# Epoch 67/75
# 110/110 [==============================] - 97s 878ms/step - loss: 0.2356 - acc: 0.9155 - val_loss: 0.6019 - val_acc: 0.8213
# Epoch 68/75
# 110/110 [==============================] - 97s 879ms/step - loss: 0.2370 - acc: 0.9144 - val_loss: 0.6393 - val_acc: 0.8077
# Epoch 69/75
# 110/110 [==============================] - 97s 881ms/step - loss: 0.2275 - acc: 0.9202 - val_loss: 0.6347 - val_acc: 0.8057
# Epoch 70/75
# 110/110 [==============================] - 97s 879ms/step - loss: 0.2286 - acc: 0.9190 - val_loss: 0.4704 - val_acc: 0.8527
# Epoch 71/75
# 110/110 [==============================] - 97s 881ms/step - loss: 0.2239 - acc: 0.9204 - val_loss: 0.5212 - val_acc: 0.8380
# Epoch 72/75
# 110/110 [==============================] - 97s 879ms/step - loss: 0.2166 - acc: 0.9247 - val_loss: 0.4407 - val_acc: 0.8567
# Epoch 73/75
# 110/110 [==============================] - 96s 873ms/step - loss: 0.2101 - acc: 0.9267 - val_loss: 0.7233 - val_acc: 0.7877
# Epoch 74/75
# 110/110 [==============================] - 95s 868ms/step - loss: 0.2095 - acc: 0.9283 - val_loss: 0.5011 - val_acc: 0.8463
# Epoch 75/75
# 110/110 [==============================] - 95s 866ms/step - loss: 0.2006 - acc: 0.9298 - val_loss: 0.4842 - val_acc: 0.8657

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(trained_model.history['acc'])
plt.plot(trained_model.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(trained_model.history['loss'])
plt.plot(trained_model.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model.evaluate_generator(test_generator)
# Out:
# [0.48424834505716957, 0.8656666666666667]

# %%
model.save_weights('Deep-Res-ception_with_heavy_BN_weights.h5')

# %%
plot_model(model, show_shapes=True, to_file='Deep-Res-ception_with_heavy_BN_weights.png')
